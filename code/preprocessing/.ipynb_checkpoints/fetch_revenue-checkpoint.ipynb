# %%
import numpy as np
import pandas as pd
import requests

# %%
url = """https://data.sfgov.org/resource/imvp-dq3v.json?$where=session_start_dt between '2019-12-01T00:00:00' and '2020-12-01T00:00:00' limit 20000000"""
response = requests.get(url)
df = pd.DataFrame(response.json())

# %%
df = df[['post_id', 'payment_type', 'session_start_dt', 'session_end_dt', 
         'meter_event_type', 'gross_paid_amt']]

# %%
df_meters = pd.read_csv('../../data/Meters/Parking_Meters.csv')
l_post = df_meters['POST_ID'].unique()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (28,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[df['post_id'].isin(l_post)].reset_index(drop=1)

# %%
df = df.reset_index()
df_meters = df_meters.reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2962                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2963                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2964             finally:
#
# <ipython-input-20-d02f1adb44bc> in <module>()
# ----> 1 df = df.reset_index()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4521         else:
# -> 4522             new_obj = self.copy()
#    4523
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in copy(self, deep)
#    5810         """
# -> 5811         data = self._data.copy(deep=deep)
#    5812         return self._constructor(data).__finalize__(self)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in copy(self, deep)
#     793
# --> 794         res = self.apply("copy", deep=deep)
#     795         res.axes = new_axes
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in copy(self, deep)
#     697         if deep:
# --> 698             values = values.copy()
#     699         return self.make_block_same_class(values, ndim=self.ndim)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
df_meters
# Out:
#            OBJECTID  PARKING_SPACE_ID MS_PAY_STATION_ID  MS_SPACE_NUM  \
# POST_ID
# 818-01520     33521            132627                 -             0
# 831-04060     33670            131615                 -             0
# 561-02041     33707            131649         561-02040             1
# 561-03160     33848            132817                 -             0
# 658-01430     33895            132860                 -             0
# ...             ...               ...               ...           ...
# 321-03180     63194            148061                 -             0
# 118-04020     64259            142583         909-00001             2
# 365-08040     60497            151609                 -             0
# 108-03240     62296            164733         903-00002            20
# 591-26040     65592            143241                 -             0
#
#           SENSOR_FLAG ON_OFFSTREET_TYPE  OSP_ID JURISDICTION  PM_DISTRICT_ID  \
# POST_ID
# 818-01520           Y                ON       0         PORT               2
# 831-04060           Y                ON       0         PORT               2
# 561-02041           N                ON       0        SFMTA               1
# 561-03160           N                ON       0        SFMTA               2
# 658-01430           E                ON       0        SFMTA               1
# ...               ...               ...     ...          ...             ...
# 321-03180           N                ON       0        SFMTA              40
# 118-04020           N               OFF     909        SFMTA              21
# 365-08040           N                ON       0        SFMTA              30
# 108-03240           N               OFF     903        SFMTA               9
# 591-26040           N                ON       0        SFMTA              31
#
#            BLOCKFACE_ID  ... NFC_KEY SPT_CODE          COLLECTION_ROUTE_DESC  \
# POST_ID                  ...
# 818-01520        818012  ...     NaN      NaN                            NaN
# 831-04060        831041  ...     NaN      NaN                            NaN
# 561-02041        561022  ...     NaN      NaN                            NaN
# 561-03160        561032  ...    3SP5      NaN                            NaN
# 658-01430        658011  ...    4RJ4      NaN       Folsom St: Unit-800 1st:
# ...                 ...  ...     ...      ...                            ...
# 321-03180        321032  ...    3UJ8      NaN           Balboa St: 200 - 500
# 118-04020        118041  ...    3DXU      NaN       Geary St at 18th St: Lot
# 365-08040        365082  ...    CF4O      NaN        Cortland Ave: 300 - 900
# 108-03240        108032  ...    4MXS      NaN     Clement St at 8th Ave: Lot
# 591-26040        591262  ...    2P7H      NaN  Ocean ave: 2300-2600 Holloway
#
#           COLLECTION_SUBROUTE_DESC                          shape  \
# POST_ID
# 818-01520                      NaN  POINT (-122.389114 37.784286)
# 831-04060                      NaN  POINT (-122.388504 37.789272)
# 561-02041                      NaN   POINT (-122.39328 37.790424)
# 561-03160                      NaN   POINT (-122.39142 37.788933)
# 658-01430           Spear Unit-300   POINT (-122.39334 37.792076)
# ...                            ...                            ...
# 321-03180          Balboa 200- 500  POINT (-122.462585 37.777363)
# 118-04020        Geary at 18th Lot   POINT (-122.477325 37.77994)
# 365-08040                 Cortland   POINT (-122.414345 37.73884)
# 108-03240      8th Ave Clement Lot   POINT (-122.46615 37.782288)
# 591-26040          Ocean 2400-2600   POINT (-122.47332 37.731815)
#
#           Neighborhoods SF Find Neighborhoods Current Police Districts  \
# POST_ID
# 818-01520            31                    31                        1
# 831-04060            30                    30                        1
# 561-02041           108                   108                        1
# 561-03160            30                    30                        1
# 658-01430           108                   108                        1
# ...                 ...                   ...                      ...
# 321-03180             5                     5                        8
# 118-04020             5                     5                        8
# 365-08040            83                    83                        9
# 108-03240             5                     5                        8
# 591-26040            62                    62                       10
#
#           Current Supervisor Districts  Analysis Neighborhoods
# POST_ID
# 818-01520                           10                       8
# 831-04060                           10                       8
# 561-02041                           10                       8
# 561-03160                           10                       8
# 658-01430                           10                       8
# ...                                ...                     ...
# 321-03180                            4                      11
# 118-04020                            4                      29
# 365-08040                            2                       2
# 108-03240                            4                      11
# 591-26040                            8                      41
#
# [33288 rows x 44 columns]

# %%
df = df.merge(df_meters[['POST_ID', 'BLOCKFACE_ID']], left_on='post_id', right_on='POST_ID')

# %%
df.to_csv('../../../Revenue.csv', index=None)

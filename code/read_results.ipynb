# %%
import glob
from tensorflow.python.summary.summary_iterator import summary_iterator
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.set()

# %%
def get_section_results(file):
    X = []
    Y = []
    for e in summary_iterator(file):
        for v in e.summary.value:
            if v.tag == 'Train_EnvstepsSoFar':
                X.append(v.simple_value)
            elif v.tag == 'Eval_AverageReturn':
                Y.append(v.simple_value)
    return X, Y

# %%
logdir = 'data/todo_15-12-2020_15-09-47/events.out.tfevents.1608073787.hayashintansMBP.lan'
eventfile = glob.glob(logdir)[0]
X_1, Y_1 = get_section_results(eventfile)

# %%
plt.figure(figsize=(10,4))
plt.plot(X_1,Y_1,c='#8AC6D1',label='PG')
# plt.plot(X,Y_2,c='#FF8080',label='PG-RTG')
# plt.plot(X,Y_3,c='#FFBA92',label='PG-RTG-NA')
plt.legend(bbox_to_anchor=(1.05, 0.75))

# %%
logdir = 'data/q1_lb_no_rtg_dsa_CartPole-v0_27-09-2020_17-41-51/events.out.tfevents.1601253711.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_1, Y_1 = get_section_results(eventfile)

logdir = 'data/q1_lb_rtg_dsa_CartPole-v0_27-09-2020_17-45-13/events.out.tfevents.1601253913.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_2, Y_2 = get_section_results(eventfile)

logdir = 'data/q1_lb_rtg_na_CartPole-v0_27-09-2020_17-47-55/events.out.tfevents.1601254075.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_3, Y_3 = get_section_results(eventfile)

# %%
plt.figure(figsize=(10,4)) 
plt.plot(X,Y_1,c='#8AC6D1',label='PG')
plt.plot(X,Y_2,c='#FF8080',label='PG-RTG')
plt.plot(X,Y_3,c='#FFBA92',label='PG-RTG-NA')
plt.legend(bbox_to_anchor=(1.05, 0.75))

# %%
logdir = 'data/q2_b200_r6e-2_InvertedPendulum-v2_27-09-2020_18-53-17/events.out.tfevents.1601257997.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_1, Y_1 = get_section_results(eventfile)

# %%
plt.figure(figsize=(10,4)) 
plt.plot(X,Y_1,c='#8AC6D1')

# %%
logdir = 'data/q3_b40000_r0.005_LunarLanderContinuous-v2_26-09-2020_22-26-40/events.out.tfevents.1601184400.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_1, Y_1 = get_section_results(eventfile)

# %%
plt.figure(figsize=(10,4)) 
plt.plot(X,Y_1,c='#8AC6D1')

# %%
logdir = 'data/q4_search_b10000_r0.005_rtg_nnbaseline_HalfCheetah-v2_26-09-2020_23-58-41/events.out.tfevents.1601189921.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_1, Y_1 = get_section_results(eventfile)

logdir = 'data/q4_search_b30000_r0.005_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_00-24-21/events.out.tfevents.1601191461.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_2, Y_2 = get_section_results(eventfile)

logdir = 'data/q4_search_b50000_r0.005_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_01-21-26/events.out.tfevents.1601194886.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_3, Y_3 = get_section_results(eventfile)

logdir = 'data/q4_search_b10000_r0.01_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_00-06-42/events.out.tfevents.1601190402.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_4, Y_4 = get_section_results(eventfile)

logdir = 'data/q4_search_b30000_r0.01_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_00-43-55/events.out.tfevents.1601192635.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_5, Y_5 = get_section_results(eventfile)

logdir = 'data/q4_search_b50000_r0.01_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_07-15-25/events.out.tfevents.1601216125.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_6, Y_6 = get_section_results(eventfile)

logdir = 'data/q4_search_b10000_r0.02_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_00-13-39/events.out.tfevents.1601190819.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_7, Y_7 = get_section_results(eventfile)

logdir = 'data/q4_search_b30000_r0.02_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_01-03-00/events.out.tfevents.1601193780.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_8, Y_8 = get_section_results(eventfile)

logdir = 'data/q4_search_b50000_r0.02_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_07-50-41/events.out.tfevents.1601218241.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_9, Y_9 = get_section_results(eventfile)

# %%
plt.figure(figsize=(10,4)) 
plt.plot(X,Y_1,c='#BBDED6',label='$b=10000,r=0.005$')
plt.plot(X,Y_2,c='#83B582',label='$b=30000,r=0.005$')
plt.plot(X,Y_3,c='#106D9C',label='$b=50000,r=0.005$')
plt.plot(X,Y_4,c='#FFB6B9',label='$b=10000,r=0.01$')
plt.plot(X,Y_5,c='#FFBA92',label='$b=30000,r=0.01$')
plt.plot(X,Y_6,c='#FF8080',label='$b=50000,r=0.01$')
plt.plot(X,Y_7,c='#08BAFF',label='$b=10000,r=0.02$')
plt.plot(X,Y_8,c='#00A2DE',label='$b=30000,r=0.02$')
plt.plot(X,Y_9,c='#106D9C',label='$b=50000,r=0.02$')
plt.legend(bbox_to_anchor=(1.05, 0.75))

# %%
logdir = 'data/q4_b50000_r0.02_HalfCheetah-v2_27-09-2020_08-22-16/events.out.tfevents.1601220136.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_1, Y_1 = get_section_results(eventfile)

logdir = 'data/q4_b50000_r0.02_rtg_HalfCheetah-v2_27-09-2020_09-05-59/events.out.tfevents.1601222759.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_2, Y_2 = get_section_results(eventfile)

logdir = 'data/q4_b50000_r0.02_nnbaseline_HalfCheetah-v2_27-09-2020_09-40-59/events.out.tfevents.1601224859.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_3, Y_3 = get_section_results(eventfile)

logdir = 'data/q4_b50000_r0.02_rtg_nnbaseline_HalfCheetah-v2_27-09-2020_10-15-21/events.out.tfevents.1601226921.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_4, Y_4 = get_section_results(eventfile)

# %%
plt.figure(figsize=(10,4)) 
plt.plot(X,Y_1,c='#8AC6D1',label='PG')
plt.plot(X,Y_2,c='#FF8080',label='PG-RTG')
plt.plot(X,Y_3,c='#FFBA92',label='PG-BASE')
plt.plot(X,Y_4,c='#BBDED6',label='PG-RTG-BASE')
plt.legend(bbox_to_anchor=(1.05, 0.75))

# %%
logdir = '../../data/q1_lb_no_rtg_dsa_CartPole-v0_27-09-2020_17-41-51/events.out.tfevents.1601253711.hayashiintans-MacBook-Pro.local'
eventfile = glob.glob(logdir)[0]
X_1, Y_1 = get_section_results(eventfile)
for i, (x, y) in enumerate(zip(X_1, Y_1)):
    print('Iteration {:d} | Train steps: {:d} | Return: {}'.format(i, int(x), y))
